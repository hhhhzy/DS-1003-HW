# %% [markdown]
# # Homework 2

# %% [markdown]
# Name: Zheyuan Hu
#
# NetID: zh2095

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ### Q1

# %%
def feature_normalization(train, test):

    for i in range(train.shape[1]):
        x_max = train[:,i].max()
        x_min = train[:,i].min()        
        # a is the rescale parameter, b is the shift parameter
        # a, b are trained from the training set
        # if the feature is constant, then do nothing to it
        if x_max == x_min:
            a = 1
            b = 0
        else:
            a = 1/(x_max-x_min)
            b = -x_min
        
        # apply the transformation on the train and test sets
        train[:,i] = a*(train[:,i]+b)
        test[:,i] = a*(test[:,i]+b)
        train_normalized = train
        test_normalized = test    
    
    return train_normalized, test_normalized

# %% [markdown]
# ### Q2

# %% [markdown]
# $J(\theta) = \frac {1}{m}\lVert X \theta - \mathbf y \Vert_2^2$

# %% [markdown]
# ### Q3

# %% [markdown]
# $\nabla J(\theta) = \frac {2}{m}(X^\top X \theta - X^\top \mathbf y)$

# %% [markdown]
# ### Q4

# %% [markdown]
# $\theta = \theta - \eta \nabla J(\theta)$

# %% [markdown]
# ### Q5

# %%
def compute_square_loss(X, y, theta):
   
    m = X.shape[0]
    norm = np.linalg.norm(X.dot(theta) - y)
    loss = norm**2/(m)   
    
    return loss

# %% [markdown]
# ### Q6

# %%
def compute_square_loss_gradient(X, y, theta):
    
    m = X.shape[0]
    grad = 2*(X.T.dot(X).dot(theta) - X.T.dot(y))/m   
    
    return grad

# %% [markdown]
# ## Batch gradient descent

# %% [markdown]
# ### Q7

# %%
def grad_checker(X, y, theta, epsilon=0.01, tolerance=1e-4):
    
    true_gradient = compute_square_loss_gradient(X, y, theta) #The true gradient
    num_features = theta.shape[0]
    approx_grad = np.zeros(num_features) #Initialize the gradient we approximate
    #TODO
    for i in range(num_features):
        e_i = np.zeros(num_features)
        e_i[i] = 1
        approx_grad[i] = (compute_square_loss(X, y, theta+epsilon*e_i) - 
                         compute_square_loss(X, y, theta-epsilon*e_i)) / (2*epsilon)   
    # If the gradient is wrong, then return 0 
    if np.linalg.norm(true_gradient - approx_grad) > tolerance:
        indicator = 0
    # if the gradient is corret, then return 1
    else:
        indicator = 1
    
    return indicator


#######################################
### Generic gradient checker
def generic_gradient_checker(X, y, theta, objective_func, gradient_func, 
                             epsilon=0.01, tolerance=1e-4):
    true_gradient = gradient_func(X, y, theta)
    num_features = theta.shape[0]
    approx_grad = np.zeros(num_features)
    #TODO
    for i in range(num_features):
        e_i = np.zeros(num_features)
        e_i[i] = 1
        approx_grad[i] = (objective_func(X, y, theta+epsilon*e_i) - 
                         objective_func(X, y, theta-epsilon*e_i)) / (2*epsilon)   
    # If the gradient is wrong, then return 0 
    if np.linalg.norm(true_gradient - approx_grad) > tolerance:
        indicator = 0
    # if the gradient is corret, then return 1
    else:
        indicator = 1
    
    return indicator

# %% [markdown]
# ### Q8

# %%
def batch_grad_descent(X, y, alpha=0.1, num_step=1000, grad_check=False):
    
    num_instances, num_features = X.shape[0], X.shape[1]
    theta_hist = np.zeros((num_step + 1, num_features))  #Initialize theta_hist
    loss_hist = np.zeros(num_step + 1)  #Initialize loss_hist
    theta = np.zeros(num_features)  #Initialize theta
    #TODO
    loss_hist[0] = compute_square_loss(X, y, theta)
    for i in range(num_step):
        grad = compute_square_loss_gradient(X, y, theta)
        if grad_check == True:
            check = grad_checker(X, y, theta, epsilon=0.01, tolerance=1e-4)
        theta = theta - alpha*grad       
        theta_hist[i+1,:] = theta
        loss = compute_square_loss(X, y, theta)
        loss_hist[i+1] = loss
    
    return loss_hist, theta_hist

# %% [markdown]
# ### Q9

# %%
from skeleton_code import*

# %%
X_train, y_train, X_test, y_test = load_data()
# Out:
# loading the dataset
# Split into Train and Test
# Scaling all to [0, 1]

# %%
# noticing that GD diverges when alpha=0,1,0.5,, so we plot a new graph to avoid scale conflict
fig, ax = plt.subplots(1,2,figsize=(20,6))
alpha_set = [0.1, 0.5]
num_step = 1000
step_set = np.arange(num_step+1)
for alpha in alpha_set:
    loss_hist, theta_hist = batch_grad_descent(X_train, y_train, alpha, num_step, grad_check=False)
    ax[0].plot(step_set, loss_hist, label = 'step size = %0.3f'%alpha)
    ax[0].set_title('Training Loss vs Num_Step with Divergent Step Size')
    ax[0].set_xlabel('number of steps')
    ax[0].set_ylabel('average squared loss')
    ax[0].legend()    


alpha_set = [0.05, 0.01, 0.005]
for alpha in alpha_set:
    loss_hist, theta_hist = batch_grad_descent(X_train, y_train, alpha, num_step, grad_check=False)
    ax[1].plot(step_set, loss_hist, label = 'step size = %0.3f'%alpha)
    ax[1].set_title('Training Loss vs Num_Step with Convergent Step Size')
    ax[1].set_xlabel('number of steps')
    ax[1].set_ylabel('average squared loss')
    ax[1].legend()    

plt.show()
# Out:
# C:\Users\52673\OneDrive\Desktop\NYU-MSDS\DS 1003 ML\1003 Homeworks\hw2\hw2\skeleton_code.py:84: RuntimeWarning: overflow encountered in multiply
#   grad = 2*(X.T.dot(X).dot(theta) - X.T.dot(y))/m
# C:\Users\52673\OneDrive\Desktop\NYU-MSDS\DS 1003 ML\1003 Homeworks\hw2\hw2\skeleton_code.py:203: RuntimeWarning: invalid value encountered in subtract
#   theta = theta - alpha*grad
# C:\Users\52673\OneDrive\Desktop\NYU-MSDS\DS 1003 ML\1003 Homeworks\hw2\hw2\skeleton_code.py:84: RuntimeWarning: overflow encountered in multiply
#   grad = 2*(X.T.dot(X).dot(theta) - X.T.dot(y))/m
# C:\Users\52673\OneDrive\Desktop\NYU-MSDS\DS 1003 ML\1003 Homeworks\hw2\hw2\skeleton_code.py:203: RuntimeWarning: invalid value encountered in subtract
#   theta = theta - alpha*grad

# %% [markdown]
# Summarize:
#
# From the above plots, we can see that GD converges at step_size <= 0.1, and diverges at step_size = 0.5. For those convergent step sizes, the larger the step_size is, the faster the GD converges.

# %% [markdown]
# ### Q10

# %%
# noticing that GD diverges when alpha=0.5,, so we plot a new graph to avoid scale conflict
fig, ax = plt.subplots(1,2,figsize=(20,6))
iteration = 5000
iteration_set = np.arange(iteration)
alpha_set = [0.1, 0.5]
num_features = X_train.shape[1]

for alpha in alpha_set:
    #Initialize theta
    theta = np.zeros(num_features)
    loss_test_set = []

    for i in range(iteration):
        grad = compute_square_loss_gradient(X_train, y_train, theta)
        theta = theta - alpha*grad
        loss_test = compute_square_loss(X_test, y_test, theta)
        loss_test_set.append(loss_test)
    ax[0].plot(iteration_set, loss_test_set, label = 'step size = %0.3f'%alpha)
    ax[0].set_title('Test Loss vs Iteration with Divergent Step Size')
    ax[0].set_xlabel('iterations')
    ax[0].set_ylabel('average squared test loss')
    ax[0].legend()  


alpha_set = [0.05, 0.01, 0.005]
for alpha in alpha_set:
    #Initialize theta
    theta = np.zeros(num_features)
    loss_test_set = []

    for i in range(iteration):
        grad = compute_square_loss_gradient(X_train, y_train, theta)
        theta = theta - alpha*grad
        loss_test = compute_square_loss(X_test, y_test, theta)
        loss_test_set.append(loss_test)
    
    ax[1].plot(iteration_set, loss_test_set, label = 'step size = %0.3f'%alpha)
    ax[1].set_title('Test Loss vs Iteration with Convergent Step Size')
    ax[1].set_xlabel('iterations')
    ax[1].set_ylabel('average squared test loss')
    ax[1].legend()    

plt.show()
# Out:
# C:\Users\52673\OneDrive\Desktop\NYU-MSDS\DS 1003 ML\1003 Homeworks\hw2\hw2\skeleton_code.py:84: RuntimeWarning: overflow encountered in multiply
#   grad = 2*(X.T.dot(X).dot(theta) - X.T.dot(y))/m
# <ipython-input-106-438e472db8df>:15: RuntimeWarning: invalid value encountered in subtract
#   theta = theta - alpha*grad
# C:\Users\52673\OneDrive\Desktop\NYU-MSDS\DS 1003 ML\1003 Homeworks\hw2\hw2\skeleton_code.py:84: RuntimeWarning: overflow encountered in multiply
#   grad = 2*(X.T.dot(X).dot(theta) - X.T.dot(y))/m
# <ipython-input-106-438e472db8df>:15: RuntimeWarning: invalid value encountered in subtract
#   theta = theta - alpha*grad

# %% [markdown]
# For those convergent step sizes, the larger the step_size is, the faster $\theta$ overfits on the test set.

# %% [markdown]
# ## Ridge Regression

# %% [markdown]
# ### Q11

# %% [markdown]
# Gradient of $J_\lambda(\theta)$:
#
# $\nabla J_\lambda(\theta) = \frac {2}{m}(X^\top X \theta - X^\top \mathbf y) + 2\lambda \theta$

# %% [markdown]
# The expression for updating θ:
#
# $\theta = \theta - \eta \nabla J_\lambda(\theta)$

# %% [markdown]
# ### Q12

# %%
def compute_regularized_square_loss_gradient(X, y, theta, lambda_reg):
    
    m = X.shape[0]
    grad = 2*(X.T.dot(X).dot(theta) - X.T.dot(y))/m + 2*lambda_reg*theta
    
    return grad

# %% [markdown]
# ### Q13

# %%
def regularized_grad_descent(X, y, alpha=0.05, lambda_reg=10**-2, num_step=1000):
    
    num_instances, num_features = X.shape[0], X.shape[1]
    theta = np.zeros(num_features) #Initialize theta
    theta_hist = np.zeros((num_step+1, num_features)) #Initialize theta_hist
    loss_hist = np.zeros(num_step+1) #Initialize loss_hist
    #TODO
    loss_hist[0] = compute_square_loss(X, y, theta)
    for i in range(num_step):
        grad = compute_regularized_square_loss_gradient(X, y, theta, lambda_reg)
        theta = theta - alpha*grad       
        theta_hist[i+1,:] = theta
        loss = compute_square_loss(X, y, theta)
        loss_hist[i+1] = loss
    
    return loss_hist, theta_hist

# %% [markdown]
# ### Q14

# %%
# plot training average square loss as a function of the training iterations 
fig, ax = plt.subplots(1,2,figsize=(20,6))
# here choose alpha=0.02
alpha = 0.02
lamb_set = [1e-5, 1e-4, 1e-3, 5e-3, 1e-2, 1e-1, 1]
iteration = 2000
iter_set = np.arange(iteration+1)
for lambda_reg in lamb_set:
    loss_hist, theta_hist = regularized_grad_descent(X_train, y_train, alpha, lambda_reg, iteration)
    ax[0].plot(iter_set, loss_hist, label = 'lambda_reg = %f'%lambda_reg)
    ax[0].set_title('Training Loss vs Iteration with Different Regularization Terms')
    ax[0].set_xlabel('iterations')
    ax[0].set_ylabel('training loss')
    ax[0].legend() 
    

# plot training average square loss as a function of the training iterations 
# here choose alpha=0.02
num_features = X_train.shape[1]
iter_set = np.arange(iteration)

for lambda_reg in lamb_set:
    #Initialize theta
    theta = np.zeros(num_features)
    loss_test_set = []
    for i in range(iteration):
        grad = compute_regularized_square_loss_gradient(X_train, y_train, theta, lambda_reg)
        theta = theta - alpha*grad
        loss_test = compute_square_loss(X_test, y_test, theta)
        loss_test_set.append(loss_test)
    
    ax[1].plot(iter_set, loss_test_set, label = 'lambda_reg = %f'%lambda_reg)
    ax[1].set_title('Test Loss vs Iteration with Different Regularization Terms')
    ax[1].set_xlabel('iterations')
    ax[1].set_ylabel('test loss')
    ax[1].legend() 
plt.show()

# %% [markdown]
# Smaller $\lambda$ tend to perform better on the training set. However, the smaller the $\lambda$ is, the more $\theta$ overfits on the test set.

# %% [markdown]
# ### Q15

# %%
fig, ax = plt.subplots(1,2,figsize=(20,6))
# here choose alpha=0.02
alpha = 0.02
iteration = 1000
lamb_set = [1e-5, 1e-4, 1e-3, 5e-3, 1e-2, 5e-2, 1e-1, 1]
loss_train_set = []
loss_test_set = []

for lambda_reg in lamb_set:
    loss_hist, theta_hist = regularized_grad_descent(X_train, y_train, alpha, lambda_reg, iteration)
    loss_train = loss_hist[-1]
    theta = theta_hist[-1]
    loss_test = compute_square_loss(X_test, y_test, theta)
    loss_train_set.append(loss_train)
    loss_test_set.append(loss_test)

ax[0].plot(lamb_set, loss_train_set, 'x--')
ax[0].set_title('Training Loss after %d Iterations vs Lambda'%iteration)
ax[0].set_xscale('log')
ax[0].set_xlabel('log of lambda')
ax[0].set_ylabel('training loss')
    
ax[1].plot(lamb_set, loss_test_set, 'x--')
ax[1].set_title('Test Loss after %d Iterations vs Lambda'%iteration)
ax[1].set_xscale('log')
ax[1].set_xlabel('log of lambda')
ax[1].set_ylabel('test loss')

plt.show()

# %% [markdown]
# Based on the performance on the test set, I would choose $\lambda = 10^{-2}$

# %% [markdown]
# ### Q16

# %%
fig, ax = plt.subplots(figsize=(10,6))
# here choose alpha=0.02
alpha = 0.02
iteration = 1000
lamb_set = [1e-5, 1e-4, 1e-3, 5e-3, 1e-2, 5e-2, 1e-1,1]
loss_min_set = []
loss_final_set = []
for lambda_reg in lamb_set:
    #Initialize theta
    theta = np.zeros(num_features)
    loss_test_set = []
    for i in range(iteration):
        grad = compute_regularized_square_loss_gradient(X_train, y_train, theta, lambda_reg)
        theta = theta - alpha*grad
        loss_test = compute_square_loss(X_test, y_test, theta)
        loss_test_set.append(loss_test)
    
    loss_min = min(loss_test_set)
    loss_min_set.append(loss_min)
    loss_final = loss_test_set[-1]
    loss_final_set.append(loss_final)
      
ax.plot(lamb_set, loss_final_set, 'x--', label = 'final loss after training')
ax.plot(lamb_set, loss_min_set, 'x--', label = 'min loss alone training')
ax.set_title('Test Loss vs Lambda')
ax.set_xscale('log')
ax.set_xlabel('log of lambda')
ax.set_ylabel('test loss')
ax.legend()

plt.show()

best_lambda = lamb_set[np.argmin(loss_min_set)]
print('The best lambda is', best_lambda)
# Out:
# The best lambda is 0.01

# %% [markdown]
# Yes, I would still select $\lambda = 10^{-2}$, since its corresponding minimum loss is the smallest among all $\lambda$s

# %% [markdown]
# ### Q17

# %% [markdown]
# I would select the $\theta$ that is trained with the regularization parameter $\lambda = 10^{-2}$, and is at the iteration where the test loss reaches its minimum.
#
# Based on the previous analysis and graphs, the model with $\lambda = 10^{-2}$ has the best performance, and the reason I choose the $\theta$ corresponding to the min test loss during training rather than the $\theta$ after the entire training is to prevent the overfitting caused by too many training iterations.

# %% [markdown]
# ## Logistic regression

# %% [markdown]
# ### Q23

# %% [markdown]
# The logistic loss function is:
# $$ \ell_{logistic} = log(1+e^{-m}) \text{, where } m = yh_{\theta,b}(x)$$
#
# So the object funtion $L(\theta)$ over $\{x_i, y_i\}_{i=1}^m$ is:
# $$L(\theta) = \frac 1 m \sum_{i=1}^m  \log (1 + e^{y_i h_{\theta, b}(x_i)})$$
#
# Want to show that
# $$ \log (1 + e^{y_i h_{\theta, b}(x_i)}) = \frac 1 2 (1 + y_i) \log (1 + e^{-h_{\theta, b}(x_i)}) +  (1 - y_i) \log(1 + e^{h_{\theta, b}(x_i)})$$
#
# Here $y_i$ is either 1 or -1, for $y_i = 1$,
# $$RHS = LHS = \log (1 + e^{h_{\theta, b}(x_i)})$$
#
# similarly, for $y_i = -1$,
# $$RHS = LHS = \log (1 + e^{-h_{\theta, b}(x_i)})$$
#
# so the equation holds for both $y_i = 1, -1$
#
# Therefore,
# $$L(\theta) =  \frac 1 {2 m} \sum_{i=1}^m  (1 + y_i) \log ( 1 + e^{- h_{\theta, b}( x_i)}) +  (1 - y) \log(1 + e^{h_{\theta, b}( x_i)})$$

# %% [markdown]
# ### Q24

# %% [markdown]
# The loss function with $\ell_1$ regularization term $\alpha$ is:
# $$L(\theta) =  \frac 1 {2 m} \sum_{i=1}^m  (1 + y_i) \log ( 1 + e^{- h_{\theta, b}( x_i)}) +  (1 - y) \log(1 + e^{h_{\theta, b}( x_i)}) + \alpha \lVert \theta \Vert_1$$
#
# where $\lVert \theta \Vert_1 = \lvert \theta_1 \vert + \lvert \theta_2 \vert + \cdots + \lvert \theta_{n} \vert$ is the $\ell_1$ norm

# %% [markdown]
# ### Q25

# %%
def classification_error(clf, X, y):
    ## TODO
    n = X.shape[0]
    y_pred = clf.predict(X)
    err = sum(y_pred != y)/n
    
    return err

X_train, X_test, y_train, y_test = pre_process_mnist_01()

clf = SGDClassifier(loss='log', max_iter=1000, 
                    tol=1e-3,
                    penalty='l1', alpha=0.01, 
                    learning_rate='invscaling', 
                    power_t=0.5,                
                    eta0=0.01,
                    verbose=1)
clf.fit(X_train, y_train)

test = classification_error(clf, X_test, y_test)
train = classification_error(clf, X_train, y_train)
print('train: ', train, end='\t')
print('test: ', test)
# Out:
# -- Epoch 1
# Norm: 0.74, NNZs: 313, Bias: -0.007640, T: 9902, Avg. loss: 0.044237
# Total training time: 0.03 seconds.
# -- Epoch 2
# Norm: 0.83, NNZs: 272, Bias: -0.008024, T: 19804, Avg. loss: 0.032060
# Total training time: 0.06 seconds.
# -- Epoch 3
# Norm: 0.88, NNZs: 253, Bias: -0.007908, T: 29706, Avg. loss: 0.030068
# Total training time: 0.09 seconds.
# -- Epoch 4
# Norm: 0.93, NNZs: 242, Bias: -0.007640, T: 39608, Avg. loss: 0.029219
# Total training time: 0.12 seconds.
# -- Epoch 5
# Norm: 0.96, NNZs: 237, Bias: -0.007293, T: 49510, Avg. loss: 0.028547
# Total training time: 0.15 seconds.
# -- Epoch 6
# Norm: 1.00, NNZs: 230, Bias: -0.006902, T: 59412, Avg. loss: 0.028162
# Total training time: 0.18 seconds.
# -- Epoch 7
# Norm: 1.02, NNZs: 225, Bias: -0.006492, T: 69314, Avg. loss: 0.027843
# Total training time: 0.21 seconds.
# -- Epoch 8
# Norm: 1.05, NNZs: 217, Bias: -0.006060, T: 79216, Avg. loss: 0.027601
# Total training time: 0.25 seconds.
# Convergence after 8 epochs took 0.25 seconds
# train:  0.00222177337911533	test:  0.0012300123001230013

# %%
# check if the function returns the same value as 1 - clf.score(X, y)
train = 1 - clf.score(X_train, y_train)
test = 1 - clf.score(X_test, y_test)

print('train: ', train, end='\t')
print('test: ', test)
# Out:
# train:  0.0022217733791153327	test:  0.0012300123001229846

# %% [markdown]
# ### Q26

# %%
from mnist_classification_source_code import*

# %%
X_train, X_test, y_train, y_test = pre_process_mnist_01()

N_train = 100
X_train, y_train = sub_sample(N_train, X_train, y_train)

# %%
alpha_set = [1e-4, 2e-4, 5e-4, 1e-3, 2e-3, 5e-3, 1e-2, 2e-2, 5e-2, 1e-1]
err_mean_set = []
err_std_set = []
for alpha in alpha_set:
    err_set = []
    for i in range(10):
        clf = SGDClassifier(loss='log', max_iter=1000, 
                    tol=1e-3,
                    penalty='l1', alpha=alpha, 
                    learning_rate='invscaling', 
                    power_t=0.5,                
                    eta0=0.01,
                    verbose=1)
    
        clf.fit(X_train, y_train)
        err = classification_error(clf, X_test, y_test)
        err_set.append(err)
    
    err_mean = np.mean(err_set)
    err_std = np.std(err_set)
    err_mean_set.append(err_mean)
    err_std_set.append(err_std)
# Out:
# -- Epoch 1
# Norm: 0.30, NNZs: 607, Bias: 0.006820, T: 100, Avg. loss: 0.156853
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 0.34, NNZs: 607, Bias: 0.007928, T: 200, Avg. loss: 0.074943
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 0.36, NNZs: 607, Bias: 0.008634, T: 300, Avg. loss: 0.060653
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 0
# Total training time: 0.01 seconds.
# -- Epoch 13
# Norm: 0.45, NNZs: 607, Bias: 0.018575, T: 1300, Avg. loss: 0.030647
# Total training time: 0.01 seconds.
# -- Epoch 14
# Norm: 0.46, NNZs: 606, Bias: 0.018683, T: 1400, Avg. loss: 0.029653
# Total training time: 0.01 seconds.
# -- Epoch 15
# Norm: 0.46, NNZs: 606, Bias: 0.018783, T: 1500, Avg. loss: 0.028759
# Total training time: 0.01 seconds.
# -- Epoch 16
# Norm: 0.46, NNZs: 606, Bias: 0.018876, T: 1600, Avg. loss: 0.027946
# Total training time: 0.01 seconds.
# -- Epoch 17
# Norm: 0.47, NNZs: 607, Bias: 0.018963, T: 1700, Avg. loss: 0.027203
# Total training time: 0.01 seconds.
# -- Epoch 18
# Norm: 0.47, NNZs: 607, Bias: 0.019044, T: 1800, Avg. loss: 0.026519
# Total training time: 0.01 seconds.
# Convergence after 18 epochs took 0.01 seconds
# -- Epoch 1
# Norm: 0.30, NNZs: 607, Bias: 0.009276, T: 100, Avg. loss: 0.157866
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 0.34, NNZs: 606, Bias: 0.010473, T: 200, Avg. loss: 0.072381
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 0.36, NNZs: 607, Bias: 0.011132, T: 300, Avg. loss: 0.058376
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 0.38, NNZs: 607, Bias: 0.011619, T: 400, Avg. loss: 0.050845
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 0.39, NNZs: 607, Bias: 0.011984, T: 500, Avg. loss: 0.045888
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 0.40, NNZs: 607, Bias: 0.012267, T: 600, Avg. loss: 0.042277
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 0.41, NNZs: 607, Bias: 0.012505, T: 700, Avg. loss: 0.039479
# Total training time: 0.01 seconds.
# -- Epoch 8
# Norm: 0.42, NNZs: 607, Bias: 0.012718, T: 800, Avg. loss: 0.037223
# Total training time: 0.01 seconds.
# -- Epoch 9
# Norm: 0.43, NNZs: 607, Bias: 0.012900, T: 900, Avg. loss: 0.035360
# Total training time: 0.01 seconds.
# -- Epoch 10
# Norm: 0.43, NNZs: 607, Bias: 0.013068, T: 1000, Avg. loss: 0.033767
# Total training time: 0.01 seconds.
# -- Epoch 11
# Norm: 0.44, NNZs: 607, Bias: 0.013219, T: 1100, Avg. loss: 0.032393
# Total training time: 0.01 seconds.
# -- Epoch 12
# Norm: 0.44, NNZs: 607, Bias: 0.013356, T: 1200, Avg. loss: 0.031183
# Total training time: 0.01 seconds.
# -- Epoch 13
# Norm: 0.45, NNZs: 607, Bias: 0.013485, T: 1300, Avg. loss: 0.030113
# Total training time: 0.01 seconds.
# -- Epoch 14
# Norm: 0.45, NNZs: 605, Bias: 0.013603, T: 1400, Avg. loss: 0.029158
# Total training time: 0.01 seconds.
# -- Epoch 15
# Norm: 0.46, NNZs: 605, Bias: 0.013712, T: 1500, Avg. loss: 0.028296
# Total training time: 0.01 seconds.
# -- Epoch 16
# Norm: 0.46, NNZs: 605, Bias: 0.013813, T: 1600, Avg. loss: 0.027509
# Total training time: 0.01 seconds.
# -- Epoch 17
# Norm: 0.47, NNZs: 606, Bias: 0.013906, T: 1700, Avg. loss: 0.026791
# Total training time: 0.01 seconds.
# -- Epoch 18
# Norm: 0.47, NNZs: 606, Bias: 0.013993, T: 1800, Avg. loss: 0.026129
# Total training time: 0.01 seconds.
# Convergence after 18 epochs took 0.01 seconds
# -- Epoch 1
# Norm: 0.30, NNZs: 607, Bias: 0.011313, T: 100, Avg. loss: 0.162275
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 0
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 0.41, NNZs: 607, Bias: 0.014573, T: 700, Avg. loss: 0.039737
# Total training time: 0.01 seconds.
# -- Epoch 8
# Norm: 0.42, NNZs: 607, Bias: 0.014789, T: 800, Avg. loss: 0.037428
# Total training time: 0.01 seconds.
# -- Epoch 9
# Norm: 0.43, NNZs: 607, Bias: 0.014984, T: 900, Avg. loss: 0.035520
# Total training time: 0.01 seconds.
# -- Epoch 10
# Norm: 0.43, NNZs: 606, Bias: 0.015148, T: 1000, Avg. loss: 0.033898
# Total training time: 0.01 seconds.
# -- Epoch 11
# Norm: 0.44, NNZs: 605, Bias: 0.015301, T: 1100, Avg. loss: 0.032494
# Total training time: 0.01 seconds.
# -- Epoch 12
# Norm: 0.44, NNZs: 606, Bias: 0.015436, T: 1200, Avg. loss: 0.031264
# Total training time: 0.01 seconds.
# -- Epoch 13
# Norm: 0.45, NNZs: 606, Bias: 0.015560, T: 1300, Avg. loss: 0.030172
# Total training time: 0.01 seconds.
# -- Epoch 14
# Norm: 0.45, NNZs: 607, Bias: 0.015678, T: 1400, Avg. loss: 0.029199
# Total training time: 0.01 seconds.
# -- Epoch 15
# Norm: 0.46, NNZs: 607, Bias: 0.015785, T: 1500, Avg. loss: 0.028322
# Total training time: 0.01 seconds.
# -- Epoch 16
# Norm: 0.46, NNZs: 607, Bias: 0.015887, T: 1600, Avg. loss: 0.027526
# Total training time: 0.01 seconds.
# -- Epoch 17
# Norm: 0.47, NNZs: 607, Bias: 0.015982, T: 1700, Avg. loss: 0.026797
# Total training time: 0.01 seconds.
# -- Epoch 18
# Norm: 0.47, NNZs: 607, Bias: 0.016072, T: 1800, Avg. loss: 0.026127
# Total training time: 0.01 seconds.
# Convergence after 18 epochs took 0.01 seconds
# -- Epoch 1
# Norm: 0.30, NNZs: 545, Bias: 0.001640, T: 100, Avg. loss: 0.163031
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 0.34, NNZs: 607, Bias: 0.003536, T: 200, Avg. loss: 0.071967
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 0.36, NNZs: 606, Bias: 0.004566, T: 300, Avg. loss: 0.057384
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 0.38, NNZs: 606, Bias: 0.005339, T: 400, Avg. loss: 0.049672
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 0.39, NNZs: 606, Bias: 0.005905, T: 500, Avg. loss: 0.044694
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 0.40, NNZs: 605, Bias: 0.006382, T: 600, Avg. loss: 0.041094
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 0.41, NNZs: 607, Bias: 0.006782, T: 700, Avg. loss: 0.038316
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 0.42, NNZs: 607, Bias: 0.007127, T: 800, Avg. loss: 0.036091
# Total training time: 0.01 seconds.
# -- Epoch 9
# Norm: 0.43, NNZs: 607, Bias: 0.007431, T: 900, Avg. loss: 0.034247
# Total training time: 0.01 seconds.
# -- Epoch 10
# Norm: 0.44, NNZs: 606, Bias: 0.007707, T: 1000, Avg. loss: 0.032682
# Total training time: 0.01 seconds.
# -- Epoch 11
# Norm: 0.44, NNZs: 607, Bias: 0.007951, T: 1100, Avg. loss: 0.031331
# Total training time: 0.01 seconds.
# -- Epoch 12
# Norm: 0.45, NNZs: 607, Bias: 0.008176, T: 1200, Avg. loss: 0.030152
# Total training time: 0.01 seconds.
# -- Epoch 13
# Norm: 0.45, NNZs: 607, Bias: 0.008389, T: 1300, Avg. loss: 0.029107
# Total training time: 0.01 seconds.
# -- Epoch 14
# Norm: 0.46, NNZs: 605, Bias: 0.008583, T: 1400, Avg. loss: 0.028173
# Total training time: 0.01 seconds.
# -- Epoch 15
# Total training time: 0.00 seconds.
# -- Epoch 9
# Norm: 0.44, NNZs: 523, Bias: 0.008999, T: 900, Avg. loss: 0.034928
# Total training time: 0.01 seconds.
# -- Epoch 10
# Norm: 0.45, NNZs: 519, Bias: 0.009128, T: 1000, Avg. loss: 0.033353
# Total training time: 0.01 seconds.
# -- Epoch 11
# Norm: 0.46, NNZs: 513, Bias: 0.009247, T: 1100, Avg. loss: 0.031996
# Total training time: 0.01 seconds.
# -- Epoch 12
# Norm: 0.46, NNZs: 509, Bias: 0.009356, T: 1200, Avg. loss: 0.030808
# Total training time: 0.01 seconds.
# -- Epoch 13
# Norm: 0.47, NNZs: 505, Bias: 0.009451, T: 1300, Avg. loss: 0.029753
# Total training time: 0.01 seconds.
# -- Epoch 14
# Norm: 0.47, NNZs: 503, Bias: 0.009541, T: 1400, Avg. loss: 0.028809
# Total training time: 0.01 seconds.
# -- Epoch 15
# Norm: 0.47, NNZs: 503, Bias: 0.009626, T: 1500, Avg. loss: 0.027956
# Total training time: 0.01 seconds.
# -- Epoch 16
# Norm: 0.48, NNZs: 502, Bias: 0.009706, T: 1600, Avg. loss: 0.027183
# Total training time: 0.01 seconds.
# -- Epoch 17
# Norm: 0.48, NNZs: 498, Bias: 0.009783, T: 1700, Avg. loss: 0.026476
# Total training time: 0.01 seconds.
# -- Epoch 18
# Norm: 0.49, NNZs: 495, Bias: 0.009853, T: 1800, Avg. loss: 0.025827
# Total training time: 0.01 seconds.
# Convergence after 18 epochs took 0.01 seconds
# -- Epoch 1
# Norm: 0.30, NNZs: 607, Bias: 0.010509, T: 100, Avg. loss: 0.166794
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 0.34, NNZs: 607, Bias: 0.011263, T: 200, Avg. loss: 0.073681
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 0.36, NNZs: 605, Bias: 0.011951, T: 300, Avg. loss: 0.058740
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 0.38, NNZs: 607, Bias: 0.012476, T: 400, Avg. loss: 0.050946
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 0.39, NNZs: 606, Bias: 0.012872, T: 500, Avg. loss: 0.045842
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 0.40, NNZs: 607, Bias: 0.013190, T: 600, Avg. loss: 0.042148
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 0.41, NNZs: 606, Bias: 0.013457, T: 700, Avg. loss: 0.039295
# Total training time: 0.01 seconds.
# -- Epoch 8
# Norm: 0.42, NNZs: 606, Bias: 0.013689, T: 800, Avg. loss: 0.037008
# Total training time: 0.01 seconds.
# -- Epoch 9
# Norm: 0.43, NNZs: 607, Bias: 0.013896, T: 900, Avg. loss: 0.035123
# Total training time: 0.01 seconds.
# -- Epoch 10
# Norm: 0.44, NNZs: 605, Bias: 0.014078, T: 1000, Avg. loss: 0.033524
# Total training time: 0.01 seconds.
# -- Epoch 11
# Norm: 0.44, NNZs: 604, Bias: 0.014246, T: 1100, Avg. loss: 0.032149
# Total training time: 0.01 seconds.
# -- Epoch 12
# Norm: 0.45, NNZs: 605, Bias: 0.014399, T: 1200, Avg. loss: 0.030942
# Total training time: 0.01 seconds.
# -- Epoch 13
# Norm: 0.45, NNZs: 605, Bias: 0.014536, T: 1300, Avg. loss: 0.029876
# Total training time: 0.01 seconds.
# -- Epoch 14
# Norm: 0.46, NNZs: 605, Bias: 0.014661, T: 1400, Avg. loss: 0.028919
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 0.42, NNZs: 486, Bias: 0.012237, T: 700, Avg. loss: 0.039671
# Total training time: 0.01 seconds.
# -- Epoch 8
# Norm: 0.43, NNZs: 484, Bias: 0.012545, T: 800, Avg. loss: 0.037399
# Total training time: 0.01 seconds.
# -- Epoch 9
# Norm: 0.44, NNZs: 481, Bias: 0.012823, T: 900, Avg. loss: 0.035518
# Total training time: 0.01 seconds.
# -- Epoch 10
# Norm: 0.44, NNZs: 480, Bias: 0.013071, T: 1000, Avg. loss: 0.033916
# Total training time: 0.01 seconds.
# -- Epoch 11
# Norm: 0.45, NNZs: 479, Bias: 0.013295, T: 1100, Avg. loss: 0.032535
# Total training time: 0.01 seconds.
# -- Epoch 12
# Norm: 0.45, NNZs: 478, Bias: 0.013500, T: 1200, Avg. loss: 0.031331
# Total training time: 0.01 seconds.
# -- Epoch 13
# Norm: 0.46, NNZs: 474, Bias: 0.013688, T: 1300, Avg. loss: 0.030262
# Total training time: 0.01 seconds.
# -- Epoch 14
# Norm: 0.46, NNZs: 472, Bias: 0.013863, T: 1400, Avg. loss: 0.029308
# Total training time: 0.01 seconds.
# -- Epoch 15
# Norm: 0.47, NNZs: 471, Bias: 0.014027, T: 1500, Avg. loss: 0.028448
# Total training time: 0.01 seconds.
# ...
# Convergence after 17 epochs took 0.01 seconds
# -- Epoch 1
# Norm: 0.33, NNZs: 204, Bias: -0.000248, T: 100, Avg. loss: 0.283940
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 0.39, NNZs: 189, Bias: 0.003312, T: 200, Avg. loss: 0.214489
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 0.43, NNZs: 171, Bias: 0.005950, T: 300, Avg. loss: 0.205477
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 0.46, NNZs: 158, Bias: 0.008143, T: 400, Avg. loss: 0.198786
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 0.49, NNZs: 154, Bias: 0.010001, T: 500, Avg. loss: 0.195737
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 0.51, NNZs: 147, Bias: 0.011649, T: 600, Avg. loss: 0.192128
# Total training time: 0.01 seconds.
# -- Epoch 7
# Norm: 0.53, NNZs: 142, Bias: 0.013198, T: 700, Avg. loss: 0.190064
# Total training time: 0.01 seconds.
# -- Epoch 8
# Norm: 0.55, NNZs: 137, Bias: 0.014604, T: 800, Avg. loss: 0.188462
# Total training time: 0.01 seconds.
# -- Epoch 9
# Norm: 0.56, NNZs: 135, Bias: 0.015929, T: 900, Avg. loss: 0.186350
# Total training time: 0.01 seconds.
# -- Epoch 10
# Norm: 0.58, NNZs: 130, Bias: 0.017163, T: 1000, Avg. loss: 0.185425
# Total training time: 0.01 seconds.
# -- Epoch 11
# Norm: 0.59, NNZs: 128, Bias: 0.018335, T: 1100, Avg. loss: 0.184347
# Total training time: 0.01 seconds.
# -- Epoch 12
# Norm: 0.60, NNZs: 126, Bias: 0.019437, T: 1200, Avg. loss: 0.183087
# Total training time: 0.01 seconds.
# -- Epoch 13
# Norm: 0.61, NNZs: 122, Bias: 0.020497, T: 1300, Avg. loss: 0.181862
# Total training time: 0.01 seconds.
# -- Epoch 14
# Norm: 0.62, NNZs: 120, Bias: 0.021510, T: 1400, Avg. loss: 0.181089
# Total training time: 0.01 seconds.
# -- Epoch 15
# Norm: 0.64, NNZs: 118, Bias: 0.022481, T: 1500, Avg. loss: 0.180438
# Total training time: 0.01 seconds.
# -- Epoch 16
# Norm: 0.65, NNZs: 117, Bias: 0.023410, T: 1600, Avg. loss: 0.179834
# Total training time: 0.01 seconds.
# -- Epoch 17
# Norm: 0.65, NNZs: 114, Bias: 0.024304, T: 1700, Avg. loss: 0.178901
# Total training time: 0.01 seconds.
# -- Epoch 18
# Norm: 0.66, NNZs: 113, Bias: 0.025172, T: 1800, Avg. loss: 0.178128
# Total training time: 0.01 seconds.
# Convergence after 18 epochs took 0.01 seconds
# -- Epoch 1
# Norm: 0.32, NNZs: 214, Bias: 0.021604, T: 100, Avg. loss: 0.281046
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 0
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 0.53, NNZs: 151, Bias: 0.029968, T: 700, Avg. loss: 0.189767
# Total training time: 0.01 seconds.
# -- Epoch 8
# Norm: 0.54, NNZs: 145, Bias: 0.031250, T: 800, Avg. loss: 0.187593
# Total training time: 0.01 seconds.
# -- Epoch 9
# Norm: 0.56, NNZs: 139, Bias: 0.032442, T: 900, Avg. loss: 0.185983
# Total training time: 0.01 seconds.
# -- Epoch 10
# Norm: 0.57, NNZs: 134, Bias: 0.033587, T: 1000, Avg. loss: 0.184385
# Total training time: 0.01 seconds.
# -- Epoch 11
# Norm: 0.59, NNZs: 130, Bias: 0.034650, T: 1100, Avg. loss: 0.182867
# Total training time: 0.01 seconds.
# -- Epoch 12
# Norm: 0.60, NNZs: 127, Bias: 0.035660, T: 1200, Avg. loss: 0.181933
# Total training time: 0.01 seconds.
# -- Epoch 13
# Norm: 0.61, NNZs: 125, Bias: 0.036636, T: 1300, Avg. loss: 0.180987
# Total training time: 0.01 seconds.
# -- Epoch 14
# Norm: 0.62, NNZs: 120, Bias: 0.037565, T: 1400, Avg. loss: 0.179725
# Total training time: 0.01 seconds.
# -- Epoch 15
# Norm: 0.63, NNZs: 120, Bias: 0.038456, T: 1500, Avg. loss: 0.179030
# Total training time: 0.01 seconds.
# -- Epoch 16
# Norm: 0.64, NNZs: 118, Bias: 0.039318, T: 1600, Avg. loss: 0.178166
# Total training time: 0.01 seconds.
# -- Epoch 17
# Norm: 0.65, NNZs: 118, Bias: 0.040145, T: 1700, Avg. loss: 0.177753
# Total training time: 0.01 seconds.
# -- Epoch 18
# Norm: 0.66, NNZs: 114, Bias: 0.040947, T: 1800, Avg. loss: 0.177181
# Total training time: 0.01 seconds.
# -- Epoch 19
# Norm: 0.67, NNZs: 114, Bias: 0.041724, T: 1900, Avg. loss: 0.176254
# Total training time: 0.01 seconds.
# Convergence after 19 epochs took 0.01 seconds
# -- Epoch 1
# Norm: 0.32, NNZs: 210, Bias: 0.016089, T: 100, Avg. loss: 0.282825
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 0.38, NNZs: 191, Bias: 0.019177, T: 200, Avg. loss: 0.214020
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 0.42, NNZs: 177, Bias: 0.021566, T: 300, Avg. loss: 0.202636
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 0.46, NNZs: 162, Bias: 0.023571, T: 400, Avg. loss: 0.196352
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 0.48, NNZs: 157, Bias: 0.025325, T: 500, Avg. loss: 0.192960
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 0.50, NNZs: 150, Bias: 0.026884, T: 600, Avg. loss: 0.190161
# Total training time: 0.01 seconds.
# -- Epoch 7
# Norm: 0.52, NNZs: 149, Bias: 0.028286, T: 700, Avg. loss: 0.187720
# Total training time: 0.01 seconds.
# -- Epoch 8
# Norm: 0.54, NNZs: 146, Bias: 0.029607, T: 800, Avg. loss: 0.186099
# Total training time: 0.01 seconds.
# -- Epoch 9
# Norm: 0.56, NNZs: 141, Bias: 0.030837, T: 900, Avg. loss: 0.185294
# Total training time: 0.01 seconds.
# -- Epoch 10
# Norm: 0.57, NNZs: 138, Bias: 0.031990, T: 1000, Avg. loss: 0.183549
# Total training time: 0.01 seconds.
# -- Epoch 11
# Norm: 0.58, NNZs: 133, Bias: 0.033074, T: 1100, Avg. loss: 0.182782
# Total training time: 0.01 seconds.
# -- Epoch 12
# Norm: 0.60, NNZs: 129, Bias: 0.034107, T: 1200, Avg. loss: 0.181936
# Total training time: 0.01 seconds.
# -- Epoch 13
# Norm: 0.61, NNZs: 128, Bias: 0.035099, T: 1300, Avg. loss: 0.180840
# Total training time: 0.01 seconds.
# -- Epoch 14
# Norm: 0.62, NNZs: 128, Bias: 0.036044, T: 1400, Avg. loss: 0.180081
# Total training time: 0.01 seconds.
# -- Epoch 15
# Norm: 0.63, NNZs: 126, Bias: 0.036952, T: 1500, Avg. loss: 0.179827
# Total training time: 0.01 seconds.
# -- Epoch 16
# Norm: 0.64, NNZs: 124, Bias: 0.037829, T: 1600, Avg. loss: 0.178923
# Total training time: 0.01 seconds.
# -- Epoch 17
# Norm: 0.65, NNZs: 119, Bias: 0.038677, T: 1700, Avg. loss: 0.178392
# Total training time: 0.01 seconds.
# -- Epoch 18
# Norm: 0.66, NNZs: 118, Bias: 0.039497, T: 1800, Avg. loss: 0.177605
# Total training time: 0.01 seconds.
# Convergence after 18 epochs took 0.01 seconds
# -- Epoch 1
# Norm: 0.33, NNZs: 219, Bias: 0.007309, T: 100, Avg. loss: 0.278519
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 0.39, NNZs: 196, Bias: 0.010937, T: 200, Avg. loss: 0.214216
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 0.43, NNZs: 181, Bias: 0.013553, T: 300, Avg. loss: 0.202144
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 0.46, NNZs: 172, Bias: 0.015737, T: 400, Avg. loss: 0.197856
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 0.49, NNZs: 165, Bias: 0.017622, T: 500, Avg. loss: 0.194375
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 0.51, NNZs: 157, Bias: 0.019249, T: 600, Avg. loss: 0.191685
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 0.53, NNZs: 150, Bias: 0.020748, T: 700, Avg. loss: 0.189910
# Total training time: 0.01 seconds.
# -- Epoch 8
# Norm: 0.55, NNZs: 146, Bias: 0.022129, T: 800, Avg. loss: 0.187883
# Total training time: 0.01 seconds.
# -- Epoch 9
# Norm: 0.56, NNZs: 139, Bias: 0.023398, T: 900, Avg. loss: 0.186177
# Total training time: 0.01 seconds.
# -- Epoch 10
# Norm: 0.58, NNZs: 138, Bias: 0.024607, T: 1000, Avg. loss: 0.184665
# Total training time: 0.01 seconds.
# -- Epoch 11
# Norm: 0.59, NNZs: 137, Bias: 0.025744, T: 1100, Avg. loss: 0.183737
# Total training time: 0.01 seconds.
# -- Epoch 12
# Norm: 0.60, NNZs: 134, Bias: 0.026806, T: 1200, Avg. loss: 0.183130
# Total training time: 0.01 seconds.
# -- Epoch 13
# Norm: 0.61, NNZs: 131, Bias: 0.027828, T: 1300, Avg. loss: 0.182247
# Total training time: 0.01 seconds.
# -- Epoch 14
# Norm: 0.62, NNZs: 130, Bias: 0.028813, T: 1400, Avg. loss: 0.181044
# Total training time: 0.01 seconds.
# -- Epoch 15
# Norm: 0.64, NNZs: 126, Bias: 0.029745, T: 1500, Avg. loss: 0.180610
# Total training time: 0.01 seconds.
# -- Epoch 16
# Norm: 0.65, NNZs: 125, Bias: 0.030650, T: 1600, Avg. loss: 0.180014
# Total training time: 0.01 seconds.
# -- Epoch 17
# Norm: 0.65, NNZs: 120, Bias: 0.031525, T: 1700, Avg. loss: 0.179377
# Total training time: 0.01 seconds.
# -- Epoch 18
# Norm: 0.66, NNZs: 114, Bias: 0.032377, T: 1800, Avg. loss: 0.178317
# Total training time: 0.01 seconds.
# -- Epoch 19
# Norm: 0.67, NNZs: 113, Bias: 0.033204, T: 1900, Avg. loss: 0.177693
# Total training time: 0.01 seconds.
# -- Epoch 20
# Norm: 0.68, NNZs: 112, Bias: 0.034002, T: 2000, Avg. loss: 0.176947
# Total training time: 0.01 seconds.
# -- Epoch 21
# Norm: 0.69, NNZs: 110, Bias: 0.034775, T: 2100, Avg. loss: 0.176655
# Total training time: 0.01 seconds.
# -- Epoch 22
# Norm: 0.70, NNZs: 107, Bias: 0.035535, T: 2200, Avg. loss: 0.175978
# Total training time: 0.02 seconds.
# -- Epoch 23
# Norm: 0.70, NNZs: 106, Bias: 0.036271, T: 2300, Avg. loss: 0.175367
# Total training time: 0.02 seconds.
# Convergence after 23 epochs took 0.02 seconds
# -- Epoch 1
# Norm: 0.33, NNZs: 228, Bias: 0.016514, T: 100, Avg. loss: 0.284448
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 0.39, NNZs: 195, Bias: 0.019613, T: 200, Avg. loss: 0.214788
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 0.43, NNZs: 185, Bias: 0.022052, T: 300, Avg. loss: 0.204075
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 0.46, NNZs: 172, Bias: 0.024080, T: 400, Avg. loss: 0.197618
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 0.48, NNZs: 163, Bias: 0.025831, T: 500, Avg. loss: 0.194506
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 0.51, NNZs: 156, Bias: 0.027410, T: 600, Avg. loss: 0.191108
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 0.53, NNZs: 147, Bias: 0.028812, T: 700, Avg. loss: 0.189039
# Total training time: 0.01 seconds.
# -- Epoch 8
# Norm: 0.54, NNZs: 140, Bias: 0.030124, T: 800, Avg. loss: 0.186960
# Total training time: 0.01 seconds.
# -- Epoch 9
# Norm: 0.56, NNZs: 136, Bias: 0.031334, T: 900, Avg. loss: 0.185034
# Total training time: 0.01 seconds.
# -- Epoch 10
# Norm: 0.57, NNZs: 132, Bias: 0.032466, T: 1000, Avg. loss: 0.183834
# Total training time: 0.01 seconds.
# -- Epoch 11
# Norm: 0.59, NNZs: 130, Bias: 0.033547, T: 1100, Avg. loss: 0.182542
# Total training time: 0.01 seconds.
# -- Epoch 12
# Norm: 0.60, NNZs: 127, Bias: 0.034566, T: 1200, Avg. loss: 0.181409
# Total training time: 0.01 seconds.
# -- Epoch 13
# Norm: 0.61, NNZs: 124, Bias: 0.035544, T: 1300, Avg. loss: 0.180729
# Total training time: 0.01 seconds.
# -- Epoch 14
# Norm: 0.62, NNZs: 123, Bias: 0.036489, T: 1400, Avg. loss: 0.179609
# Total training time: 0.01 seconds.
# -- Epoch 15
# Norm: 0.63, NNZs: 122, Bias: 0.037393, T: 1500, Avg. loss: 0.179013
# Total training time: 0.01 seconds.
# -- Epoch 16
# Norm: 0.64, NNZs: 119, Bias: 0.038272, T: 1600, Avg. loss: 0.178369
# Total training time: 0.01 seconds.
# -- Epoch 17
# Norm: 0.65, NNZs: 118, Bias: 0.039118, T: 1700, Avg. loss: 0.177765
# Total training time: 0.01 seconds.
# -- Epoch 18
# Norm: 0.66, NNZs: 116, Bias: 0.039939, T: 1800, Avg. loss: 0.177125
# Total training time: 0.01 seconds.
# -- Epoch 19
# Norm: 0.67, NNZs: 116, Bias: 0.040739, T: 1900, Avg. loss: 0.176310
# Total training time: 0.01 seconds.
# Convergence after 19 epochs took 0.01 seconds
# -- Epoch 1
# Norm: 0.32, NNZs: 231, Bias: 0.021272, T: 100, Avg. loss: 0.296578
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 0.38, NNZs: 207, Bias: 0.024716, T: 200, Avg. loss: 0.219574
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 0.42, NNZs: 181, Bias: 0.027164, T: 300, Avg. loss: 0.206999
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 0.46, NNZs: 165, Bias: 0.029106, T: 400, Avg. loss: 0.200143
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 0.48, NNZs: 160, Bias: 0.030797, T: 500, Avg. loss: 0.195178
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 0.50, NNZs: 154, Bias: 0.032292, T: 600, Avg. loss: 0.192847
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 0.52, NNZs: 152, Bias: 0.033642, T: 700, Avg. loss: 0.190138
# Total training time: 0.01 seconds.
# -- Epoch 8
# Norm: 0.54, NNZs: 148, Bias: 0.034894, T: 800, Avg. loss: 0.188321
# Total training time: 0.01 seconds.
# -- Epoch 9
# Norm: 0.56, NNZs: 143, Bias: 0.036079, T: 900, Avg. loss: 0.187478
# Total training time: 0.01 seconds.
# -- Epoch 10
# Norm: 0.57, NNZs: 137, Bias: 0.037168, T: 1000, Avg. loss: 0.185514
# Total training time: 0.01 seconds.
# -- Epoch 11
# Norm: 0.58, NNZs: 134, Bias: 0.038187, T: 1100, Avg. loss: 0.184512
# Total training time: 0.01 seconds.
# -- Epoch 12
# Norm: 0.60, NNZs: 133, Bias: 0.039174, T: 1200, Avg. loss: 0.183257
# Total training time: 0.01 seconds.
# -- Epoch 13
# Norm: 0.61, NNZs: 128, Bias: 0.040107, T: 1300, Avg. loss: 0.182418
# Total training time: 0.01 seconds.
# -- Epoch 14
# Norm: 0.62, NNZs: 124, Bias: 0.040990, T: 1400, Avg. loss: 0.181443
# Total training time: 0.01 seconds.
# -- Epoch 15
# Norm: 0.63, NNZs: 118, Bias: 0.041851, T: 1500, Avg. loss: 0.180896
# Total training time: 0.01 seconds.
# -- Epoch 16
# Norm: 0.64, NNZs: 116, Bias: 0.042688, T: 1600, Avg. loss: 0.179650
# Total training time: 0.01 seconds.
# -- Epoch 17
# Norm: 0.65, NNZs: 116, Bias: 0.043492, T: 1700, Avg. loss: 0.178863
# Total training time: 0.01 seconds.
# -- Epoch 18
# Norm: 0.66, NNZs: 113, Bias: 0.044270, T: 1800, Avg. loss: 0.177992
# Total training time: 0.01 seconds.
# -- Epoch 19
# Norm: 0.67, NNZs: 110, Bias: 0.045025, T: 1900, Avg. loss: 0.177324
# Total training time: 0.01 seconds.
# -- Epoch 20
# Norm: 0.67, NNZs: 108, Bias: 0.045758, T: 2000, Avg. loss: 0.176674
# Total training time: 0.02 seconds.
# -- Epoch 21
# Norm: 0.68, NNZs: 107, Bias: 0.046475, T: 2100, Avg. loss: 0.175907
# Total training time: 0.02 seconds.
# Convergence after 21 epochs took 0.02 seconds

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.errorbar(alpha_set, err_mean_set, err_std_set, marker='s', mfc='red')
ax.set_title('Test Classification Error vs Alpha')
ax.set_xscale('log')
ax.set_xlabel('log of alpha')
ax.set_ylabel('test classification error')

plt.show()

# %% [markdown]
# ### Q27

# %% [markdown]
# The randomness comes from the SGD algorithm, where in each iteration, we use only 1 point $(x_i,y_i)$ to determine the step direction, and this point is randomly selected.

# %% [markdown]
# ### Q28

# %%
best_alpha = alpha_set[np.argmin(err_mean_set)]

print('The optimal α among the values I tested is:', best_alpha )
# Out:
# The optimal α among the values I tested is: 0.1

# %% [markdown]
# ### Q29

# %%
alpha_set = [1e-4, 2e-4, 5e-4, 1e-3, 2e-3, 5e-3, 1e-2, 2e-2, 5e-2, 1e-1]
theta_set = np.zeros([len(alpha_set),28,28])
scale_set = []
for i in range(len(alpha_set)):
    clf = SGDClassifier(loss='log', max_iter=1000, 
                    tol=1e-3,
                    penalty='l1', alpha=alpha_set[i], 
                    learning_rate='invscaling', 
                    power_t=0.5,                
                    eta0=0.01,
                    verbose=1)
    
    clf.fit(X_train, y_train)        
    theta = clf.coef_.reshape(28,28)        
    theta_set[i] = theta
    scale = np.abs(clf.coef_).max()
    scale_set.append(scale)
# Out:
# -- Epoch 1
# Norm: 0.30, NNZs: 472, Bias: 0.000684, T: 100, Avg. loss: 0.165201
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 0.34, NNZs: 524, Bias: 0.002083, T: 200, Avg. loss: 0.072415
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 0.36, NNZs: 547, Bias: 0.003033, T: 300, Avg. loss: 0.057848
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 0.38, NNZs: 549, Bias: 0.003678, T: 400, Avg. loss: 0.050057
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 0.39, NNZs: 550, Bias: 0.004147, T: 500, Avg. loss: 0.045036
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 0.40, NNZs: 551, Bias: 0.004540, T: 600, Avg. loss: 0.041395
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 0.41, NNZs: 551, Bias: 0.004879, T: 700, Avg. loss: 0.038595
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 0.42, NNZs: 551, Bias: 0.005172, T: 800, Avg. loss: 0.036348
# Total training time: 0.00 seconds.
# -- Epoch 9
# Norm: 0.43, NNZs: 550, Bias: 0.005432, T: 900, Avg. loss: 0.034494
# Total training time: 0.00 seconds.
# -- Epoch 10
# Norm: 0.44, NNZs: 549, Bias: 0.005658, T: 1000, Avg. loss: 0.032925
# Total training time: 0.01 seconds.
# -- Epoch 11
# Norm: 0.44, NNZs: 547, Bias: 0.005870, T: 1100, Avg. loss: 0.031564
# Total training time: 0.01 seconds.
# -- Epoch 12
# Norm: 0.45, NNZs: 545, Bias: 0.006058, T: 1200, Avg. loss: 0.030376
# Total training time: 0.01 seconds.
# -- Epoch 13
# Norm: 0.45, NNZs: 545, Bias: 0.006231, T: 1300, Avg. loss: 0.029324
# Total training time: 0.01 seconds.
# -- Epoch 14
# Norm: 0.46, NNZs: 536, Bias: 0.006390, T: 1400, Avg. loss: 0.028385
# Total training time: 0.01 seconds.
# -- Epoch 15
# Norm: 0.46, NNZs: 536, Bias: 0.006539, T: 1500, Avg. loss: 0.027538
# Total training time: 0.01 seconds.
# -- Epoch 16
# Norm: 0.47, NNZs: 536, Bias: 0.006677, T: 1600, Avg. loss: 0.026771
# Total training time: 0.01 seconds.
# -- Epoch 17
# Norm: 0.47, NNZs: 534, Bias: 0.006808, T: 1700, Avg. loss: 0.026068
# Total training time: 0.01 seconds.
# -- Epoch 18
# Norm: 0.47, NNZs: 531, Bias: 0.006929, T: 1800, Avg. loss: 0.025422
# Total training time: 0.01 seconds.
# Convergence after 18 epochs took 0.01 seconds
# -- Epoch 1
# Norm: 0.30, NNZs: 607, Bias: 0.003877, T: 100, Avg. loss: 0.156140
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 0
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 0.42, NNZs: 501, Bias: 0.017236, T: 800, Avg. loss: 0.038216
# Total training time: 0.01 seconds.
# -- Epoch 9
# Norm: 0.43, NNZs: 497, Bias: 0.017456, T: 900, Avg. loss: 0.036284
# Total training time: 0.01 seconds.
# -- Epoch 10
# Norm: 0.43, NNZs: 494, Bias: 0.017654, T: 1000, Avg. loss: 0.034649
# Total training time: 0.01 seconds.
# -- Epoch 11
# Norm: 0.44, NNZs: 491, Bias: 0.017826, T: 1100, Avg. loss: 0.033236
# Total training time: 0.01 seconds.
# -- Epoch 12
# Norm: 0.45, NNZs: 491, Bias: 0.017984, T: 1200, Avg. loss: 0.031996
# Total training time: 0.01 seconds.
# -- Epoch 13
# Norm: 0.45, NNZs: 490, Bias: 0.018132, T: 1300, Avg. loss: 0.030897
# Total training time: 0.01 seconds.
# -- Epoch 14
# Norm: 0.46, NNZs: 488, Bias: 0.018265, T: 1400, Avg. loss: 0.029914
# Total training time: 0.01 seconds.
# -- Epoch 15
# Norm: 0.46, NNZs: 487, Bias: 0.018389, T: 1500, Avg. loss: 0.029030
# Total training time: 0.01 seconds.
# -- Epoch 16
# Norm: 0.46, NNZs: 486, Bias: 0.018505, T: 1600, Avg. loss: 0.028226
# Total training time: 0.01 seconds.
# -- Epoch 17
# Norm: 0.47, NNZs: 485, Bias: 0.018613, T: 1700, Avg. loss: 0.027491
# Total training time: 0.01 seconds.
# -- Epoch 18
# Norm: 0.47, NNZs: 484, Bias: 0.018716, T: 1800, Avg. loss: 0.026815
# Total training time: 0.01 seconds.
# Convergence after 18 epochs took 0.01 seconds
# -- Epoch 1
# Norm: 0.30, NNZs: 416, Bias: 0.002021, T: 100, Avg. loss: 0.156908
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 0.34, NNZs: 418, Bias: 0.003510, T: 200, Avg. loss: 0.073298
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 0.37, NNZs: 417, Bias: 0.004320, T: 300, Avg. loss: 0.059075
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 0.38, NNZs: 420, Bias: 0.004944, T: 400, Avg. loss: 0.051442
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 0.40, NNZs: 417, Bias: 0.005419, T: 500, Avg. loss: 0.046443
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 0.41, NNZs: 414, Bias: 0.005811, T: 600, Avg. loss: 0.042830
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 0.42, NNZs: 413, Bias: 0.006128, T: 700, Avg. loss: 0.040034
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 0.42, NNZs: 412, Bias: 0.006403, T: 800, Avg. loss: 0.037781
# Total training time: 0.00 seconds.
# -- Epoch 9
# Norm: 0.43, NNZs: 412, Bias: 0.006647, T: 900, Avg. loss: 0.035910
# Total training time: 0.01 seconds.
# -- Epoch 10
# Norm: 0.44, NNZs: 410, Bias: 0.006872, T: 1000, Avg. loss: 0.034327
# Total training time: 0.01 seconds.
# -- Epoch 11
# Norm: 0.44, NNZs: 409, Bias: 0.007076, T: 1100, Avg. loss: 0.032957
# Total training time: 0.01 seconds.
# -- Epoch 12
# Norm: 0.45, NNZs: 409, Bias: 0.007260, T: 1200, Avg. loss: 0.031761
# Total training time: 0.01 seconds.
# -- Epoch 13
# Norm: 0.46, NNZs: 409, Bias: 0.007429, T: 1300, Avg. loss: 0.030699
# Total training time: 0.01 seconds.
# -- Epoch 14
# Norm: 0.46, NNZs: 409, Bias: 0.007586, T: 1400, Avg. loss: 0.029750
# Total training time: 0.01 seconds.
# -- Epoch 15
# Norm: 0.46, NNZs: 409, Bias: 0.007735, T: 1500, Avg. loss: 0.028892
# Total training time: 0.01 seconds.
# -- Epoch 16
# Norm: 0.47, NNZs: 409, Bias: 0.007874, T: 1600, Avg. loss: 0.028112
# Total training time: 0.01 seconds.
# -- Epoch 17
# Norm: 0.47, NNZs: 409, Bias: 0.008004, T: 1700, Avg. loss: 0.027400
# Total training time: 0.01 seconds.
# -- Epoch 18
# Norm: 0.48, NNZs: 409, Bias: 0.008126, T: 1800, Avg. loss: 0.026747
# Total training time: 0.01 seconds.
# Convergence after 18 epochs took 0.01 seconds
# -- Epoch 1
# Norm: 0.32, NNZs: 409, Bias: -0.000903, T: 100, Avg. loss: 0.168547
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 0.36, NNZs: 406, Bias: 0.000665, T: 200, Avg. loss: 0.073541
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 0.38, NNZs: 407, Bias: 0.001546, T: 300, Avg. loss: 0.059307
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 0.39, NNZs: 408, Bias: 0.002168, T: 400, Avg. loss: 0.051729
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 0.41, NNZs: 404, Bias: 0.002653, T: 500, Avg. loss: 0.046764
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 0.42, NNZs: 403, Bias: 0.003050, T: 600, Avg. loss: 0.043218
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 0.43, NNZs: 403, Bias: 0.003395, T: 700, Avg. loss: 0.040482
# Total training time: 0.01 seconds.
# -- Epoch 8
# Norm: 0.44, NNZs: 403, Bias: 0.003702, T: 800, Avg. loss: 0.038264
# Total training time: 0.01 seconds.
# -- Epoch 9
# Norm: 0.44, NNZs: 403, Bias: 0.003971, T: 900, Avg. loss: 0.036447
# Total training time: 0.01 seconds.
# -- Epoch 10
# Norm: 0.45, NNZs: 402, Bias: 0.004214, T: 1000, Avg. loss: 0.034893
# Total training time: 0.01 seconds.
# -- Epoch 11
# Norm: 0.46, NNZs: 402, Bias: 0.004435, T: 1100, Avg. loss: 0.033559
# Total training time: 0.01 seconds.
# -- Epoch 12
# Norm: 0.46, NNZs: 402, Bias: 0.004638, T: 1200, Avg. loss: 0.032390
# Total training time: 0.01 seconds.
# -- Epoch 13
# Norm: 0.47, NNZs: 402, Bias: 0.004823, T: 1300, Avg. loss: 0.031354
# Total training time: 0.01 seconds.
# -- Epoch 14
# Norm: 0.47, NNZs: 401, Bias: 0.004995, T: 1400, Avg. loss: 0.030424
# Total training time: 0.01 seconds.
# -- Epoch 15
# Norm: 0.48, NNZs: 401, Bias: 0.005158, T: 1500, Avg. loss: 0.029587
# Total training time: 0.01 seconds.
# -- Epoch 16
# Norm: 0.48, NNZs: 399, Bias: 0.005311, T: 1600, Avg. loss: 0.028835
# Total training time: 0.01 seconds.
# -- Epoch 17
# Norm: 0.48, NNZs: 398, Bias: 0.005456, T: 1700, Avg. loss: 0.028137
# Total training time: 0.01 seconds.
# -- Epoch 18
# Norm: 0.49, NNZs: 398, Bias: 0.005593, T: 1800, Avg. loss: 0.027502
# Total training time: 0.01 seconds.
# Convergence after 18 epochs took 0.01 seconds
# -- Epoch 1
# Norm: 0.30, NNZs: 394, Bias: 0.003129, T: 100, Avg. loss: 0.161323
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 0.34, NNZs: 392, Bias: 0.004615, T: 200, Avg. loss: 0.079949
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 0
# Total training time: 0.01 seconds.
# -- Epoch 12
# Norm: 0.48, NNZs: 355, Bias: 0.015513, T: 1200, Avg. loss: 0.042365
# Total training time: 0.01 seconds.
# -- Epoch 13
# Norm: 0.49, NNZs: 354, Bias: 0.015797, T: 1300, Avg. loss: 0.041391
# Total training time: 0.01 seconds.
# -- Epoch 14
# Norm: 0.50, NNZs: 352, Bias: 0.016064, T: 1400, Avg. loss: 0.040538
# Total training time: 0.01 seconds.
# -- Epoch 15
# Norm: 0.50, NNZs: 346, Bias: 0.016317, T: 1500, Avg. loss: 0.039733
# Total training time: 0.01 seconds.
# -- Epoch 16
# Norm: 0.51, NNZs: 346, Bias: 0.016561, T: 1600, Avg. loss: 0.039028
# Total training time: 0.01 seconds.
# -- Epoch 17
# Norm: 0.51, NNZs: 345, Bias: 0.016793, T: 1700, Avg. loss: 0.038435
# Total training time: 0.01 seconds.
# Convergence after 17 epochs took 0.01 seconds
# -- Epoch 1
# Norm: 0.32, NNZs: 355, Bias: 0.009923, T: 100, Avg. loss: 0.178064
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 0.36, NNZs: 349, Bias: 0.011850, T: 200, Avg. loss: 0.094524
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 0.39, NNZs: 342, Bias: 0.013201, T: 300, Avg. loss: 0.081190
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 0.41, NNZs: 336, Bias: 0.014241, T: 400, Avg. loss: 0.073875
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 0.43, NNZs: 331, Bias: 0.015132, T: 500, Avg. loss: 0.069217
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 0.44, NNZs: 323, Bias: 0.015869, T: 600, Avg. loss: 0.066234
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 0.45, NNZs: 317, Bias: 0.016533, T: 700, Avg. loss: 0.063531
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 0.47, NNZs: 313, Bias: 0.017136, T: 800, Avg. loss: 0.061818
# Total training time: 0.01 seconds.
# -- Epoch 9
# Norm: 0.48, NNZs: 307, Bias: 0.017682, T: 900, Avg. loss: 0.060104
# Total training time: 0.01 seconds.
# -- Epoch 10
# Norm: 0.49, NNZs: 303, Bias: 0.018189, T: 1000, Avg. loss: 0.058765
# Total training time: 0.01 seconds.
# -- Epoch 11
# Norm: 0.49, NNZs: 301, Bias: 0.018669, T: 1100, Avg. loss: 0.057764
# Total training time: 0.01 seconds.
# -- Epoch 12
# Norm: 0.50, NNZs: 300, Bias: 0.019117, T: 1200, Avg. loss: 0.056596
# Total training time: 0.01 seconds.
# -- Epoch 13
# Norm: 0.51, NNZs: 295, Bias: 0.019540, T: 1300, Avg. loss: 0.055805
# Total training time: 0.01 seconds.
# -- Epoch 14
# Norm: 0.52, NNZs: 290, Bias: 0.019941, T: 1400, Avg. loss: 0.055052
# Total training time: 0.01 seconds.
# -- Epoch 15
# Norm: 0.52, NNZs: 289, Bias: 0.020322, T: 1500, Avg. loss: 0.054413
# Total training time: 0.01 seconds.
# -- Epoch 16
# Norm: 0.53, NNZs: 286, Bias: 0.020688, T: 1600, Avg. loss: 0.053724
# Total training time: 0.01 seconds.
# -- Epoch 17
# Norm: 0.54, NNZs: 284, Bias: 0.021035, T: 1700, Avg. loss: 0.053189
# Total training time: 0.01 seconds.
# Convergence after 17 epochs took 0.01 seconds
# -- Epoch 1
# Norm: 0.31, NNZs: 293, Bias: 0.014979, T: 100, Avg. loss: 0.219593
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 0.37, NNZs: 272, Bias: 0.017474, T: 200, Avg. loss: 0.141500
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 0.40, NNZs: 259, Bias: 0.019114, T: 300, Avg. loss: 0.128090
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 0.43, NNZs: 253, Bias: 0.020443, T: 400, Avg. loss: 0.121129
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 0.45, NNZs: 246, Bias: 0.021612, T: 500, Avg. loss: 0.117039
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 0.47, NNZs: 242, Bias: 0.022641, T: 600, Avg. loss: 0.114406
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 0.49, NNZs: 237, Bias: 0.023559, T: 700, Avg. loss: 0.112575
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 0.50, NNZs: 233, Bias: 0.024412, T: 800, Avg. loss: 0.111057
# Total training time: 0.01 seconds.
# -- Epoch 9
# Norm: 0.51, NNZs: 225, Bias: 0.025215, T: 900, Avg. loss: 0.109636
# Total training time: 0.01 seconds.
# -- Epoch 10
# Norm: 0.53, NNZs: 219, Bias: 0.025953, T: 1000, Avg. loss: 0.108476
# Total training time: 0.01 seconds.
# -- Epoch 11
# Norm: 0.54, NNZs: 217, Bias: 0.026651, T: 1100, Avg. loss: 0.107410
# Total training time: 0.01 seconds.
# -- Epoch 12
# Norm: 0.55, NNZs: 214, Bias: 0.027315, T: 1200, Avg. loss: 0.106194
# Total training time: 0.01 seconds.
# -- Epoch 13
# Norm: 0.56, NNZs: 211, Bias: 0.027950, T: 1300, Avg. loss: 0.105709
# Total training time: 0.01 seconds.
# -- Epoch 14
# Norm: 0.57, NNZs: 208, Bias: 0.028561, T: 1400, Avg. loss: 0.104783
# Total training time: 0.01 seconds.
# -- Epoch 15
# Norm: 0.58, NNZs: 205, Bias: 0.029147, T: 1500, Avg. loss: 0.104657
# Total training time: 0.01 seconds.
# -- Epoch 16
# Norm: 0.59, NNZs: 205, Bias: 0.029712, T: 1600, Avg. loss: 0.103525
# Total training time: 0.01 seconds.
# -- Epoch 17
# Norm: 0.59, NNZs: 200, Bias: 0.030252, T: 1700, Avg. loss: 0.103107
# Total training time: 0.01 seconds.
# -- Epoch 18
# Norm: 0.60, NNZs: 198, Bias: 0.030780, T: 1800, Avg. loss: 0.102885
# Total training time: 0.01 seconds.
# -- Epoch 19
# Norm: 0.61, NNZs: 195, Bias: 0.031290, T: 1900, Avg. loss: 0.102238
# Total training time: 0.01 seconds.
# -- Epoch 20
# Norm: 0.62, NNZs: 192, Bias: 0.031786, T: 2000, Avg. loss: 0.101809
# Total training time: 0.01 seconds.
# -- Epoch 21
# Norm: 0.62, NNZs: 191, Bias: 0.032270, T: 2100, Avg. loss: 0.101448
# Total training time: 0.01 seconds.
# Convergence after 21 epochs took 0.01 seconds
# -- Epoch 1
# Norm: 0.32, NNZs: 217, Bias: 0.021044, T: 100, Avg. loss: 0.281897
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 0.38, NNZs: 188, Bias: 0.024405, T: 200, Avg. loss: 0.213692
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 0.42, NNZs: 177, Bias: 0.026927, T: 300, Avg. loss: 0.202209
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 0.45, NNZs: 163, Bias: 0.028860, T: 400, Avg. loss: 0.197220
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 0.48, NNZs: 152, Bias: 0.030557, T: 500, Avg. loss: 0.192408
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 0.50, NNZs: 147, Bias: 0.032088, T: 600, Avg. loss: 0.188813
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 0.52, NNZs: 145, Bias: 0.033467, T: 700, Avg. loss: 0.187097
# Total training time: 0.01 seconds.
# -- Epoch 8
# Norm: 0.54, NNZs: 140, Bias: 0.034731, T: 800, Avg. loss: 0.185452
# Total training time: 0.01 seconds.
# -- Epoch 9
# Norm: 0.55, NNZs: 137, Bias: 0.035923, T: 900, Avg. loss: 0.184295
# Total training time: 0.01 seconds.
# -- Epoch 10
# Norm: 0.57, NNZs: 133, Bias: 0.037056, T: 1000, Avg. loss: 0.182209
# Total training time: 0.01 seconds.
# -- Epoch 11
# Norm: 0.58, NNZs: 132, Bias: 0.038123, T: 1100, Avg. loss: 0.181747
# Total training time: 0.01 seconds.
# -- Epoch 12
# Norm: 0.60, NNZs: 130, Bias: 0.039145, T: 1200, Avg. loss: 0.180725
# Total training time: 0.01 seconds.
# -- Epoch 13
# Norm: 0.61, NNZs: 125, Bias: 0.040110, T: 1300, Avg. loss: 0.180367
# Total training time: 0.01 seconds.
# -- Epoch 14
# Norm: 0.62, NNZs: 124, Bias: 0.041043, T: 1400, Avg. loss: 0.179097
# Total training time: 0.01 seconds.
# -- Epoch 15
# Norm: 0.63, NNZs: 122, Bias: 0.041937, T: 1500, Avg. loss: 0.178602
# Total training time: 0.01 seconds.
# -- Epoch 16
# Norm: 0.64, NNZs: 120, Bias: 0.042798, T: 1600, Avg. loss: 0.177770
# Total training time: 0.01 seconds.
# -- Epoch 17
# Norm: 0.65, NNZs: 118, Bias: 0.043627, T: 1700, Avg. loss: 0.177366
# Total training time: 0.01 seconds.
# -- Epoch 18
# Norm: 0.66, NNZs: 117, Bias: 0.044429, T: 1800, Avg. loss: 0.176582
# Total training time: 0.01 seconds.
# -- Epoch 19
# Norm: 0.67, NNZs: 112, Bias: 0.045209, T: 1900, Avg. loss: 0.175977
# Total training time: 0.01 seconds.
# Convergence after 19 epochs took 0.01 seconds

# %%
alpha_set = [1e-4, 2e-4, 5e-4, 1e-3, 2e-3, 5e-3, 1e-2, 2e-2, 5e-2, 1e-1]
fig, ax = plt.subplots(2,5,figsize=(25,10))
k = 0
for i in range(2):
    for j in range(5):   
        scale = scale_set[k]
        theta = theta_set[k]
        im = ax[i,j].imshow(theta, cmap=plt.cm.RdBu, vmax=scale, vmin=-scale)
        ax[i,j].set_title('alpha = %0.4f'%alpha_set[k])
        k += 1

fig.colorbar(im, ax=ax.ravel().tolist())
plt.show()

# %% [markdown]
# ### Q30

# %% [markdown]
# Note about $\theta$:
#
# In the visualization graph of the fitted $\theta$, the shape of the blue part representing positive coefficients looks like the number "1", while the red part representing negative coefficients looks like "0", and the position of the blue "1" and red "0" is roughly consistent with the picture of handwritten numbers. That is, for example, if $x_i$ is the vector of handwritten "1", then its non-zero values are similar placed as the positive coefficients in $\theta$, then by multiplying $x_i$ with $\theta$, the value of the preiction gets larger, thus helps predict 1.
#
# Note the effect of the regularization:
#
# We can see that as $\alpha$ goes up, those relatively small coefficients in $\theta$ is decresing and tend to approach 0. This shows that the regularization helps identify the important features, and as we penalize more on the complexity, more unimportant features would be excluded and only the important features left to be considered in the prediction model.
